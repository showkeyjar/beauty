# %%
import pandas as pd

# %%
df_data = pd.read_feather("../data/face_record.ftr")

# %%
df_data.head(5)
# Out:
#           img_id                     img_path class score
# 0  1639468859036  data/face/1639468859036.jpg  None  None
# 1  1639468871304  data/face/1639468871304.jpg  None  None
# 2  1639468894947  data/face/1639468894947.jpg  None  None
# 3  1639468907235  data/face/1639468907235.jpg  None  None
# 4  1639468918774  data/face/1639468918774.jpg  None  None

# %%
df_unique = pd.read_feather("../data/unique_face_record.ftr")

# %%
df_unique
# Out:
#      level_0  index                            img_path         img_id
# 0          0      0  data/unique_face/1639468949520.jpg  1639468949520
# 1          1      1  data/unique_face/1639468871304.jpg  1639468871304
# 2          2      2  data/unique_face/1639468889659.jpg  1639468889659
# 3          3      3  data/unique_face/1639469266642.jpg  1639469266642
# 4          4      4  data/unique_face/1639469026972.jpg  1639469026972
# ..       ...    ...                                 ...            ...
# 599      599    599  data/unique_face/1639468867020.jpg  1639468867020
# 600      600    600  data/unique_face/1639470382076.jpg  1639470382076
# 601      601    601  data/unique_face/1639469970503.jpg  1639469970503
# 602      602    602  data/unique_face/1639469269303.jpg  1639469269303
# 603      603    603  data/unique_face/1639469997767.jpg  1639469997767
#
# [604 rows x 4 columns]

# %%
df_class = pd.read_feather("../data/face_class_record.ftr")

# %%
df_class.head(5)
# Out:
#    emotion  age gender   race                                   img_path  \
# 0     fear    4    Man  asian     data/class/00/fear/4/1639468949520.jpg
# 1  neutral    3    Man  asian  data/class/22/neutral/3/1639468949520.jpg
# 2     fear    3    Man  asian     data/class/40/fear/3/1639468949520.jpg
# 3      sad    3  Woman  asian      data/class/55/sad/3/1639468949520.jpg
# 4      sad    3  Woman  white      data/class/75/sad/3/1639468949520.jpg
#
#       score
# 0  3.539840
# 1  3.446209
# 2  3.512796
# 3  3.565176
# 4  3.505558

# %%
df_data['emotion'].value_counts()
# Out:
# neutral     70
# happy       59
# fear        52
# sad         37
# angry       17
# surprise    12
# Name: emotion, dtype: int64

# %%
df_data['age'].value_counts()
# Out:
# 3.0    193
# 4.0     36
# 2.0     16
# 5.0      2
# Name: age, dtype: int64

# %%
df_data.to_hdf("../data/face_record.h5", "df")
# Out:
# D:\tools\anaconda3\envs\beauty\lib\site-packages\pandas\core\generic.py:2703: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['img_path', 'img_id', 'class', 'score'], dtype='object')]
#
#   pytables.to_hdf(

# %%
import numpy as np

# %%
test_array = np.load("../data/class/AF1000left_cheek.npy")

# %%
test_array
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [151, 160, 204],
#         [150, 156, 201],
#         [145, 151, 196]],
#
#        [[147, 152, 197],
#         [150, 153, 198],
#         [147, 150, 195],
#         ...,
#         [ 33,  26,  33],
#         [ 29,  22,  29],
#         [ 25,  21,  27]],
#
#        [[ 25,  21,  27],
#         [ 28,  23,  32],
#         [ 31,  26,  35],
#         ...,
#         [ 21,  12,  25],
#         [ 20,  11,  24],
#         [ 21,  11,  24]],
#
#        ...,
#
#        [[188, 201, 233],
#         [187, 200, 232],
#         [187, 202, 234],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [146, 157, 201],
#         [151, 160, 204],
#         [150, 156, 201]],
#
#        [[145, 151, 196],
#         [147, 152, 197],
#         [150, 153, 198],
# ...

# %%
test_array.shape
# Out:
# (11341, 11341, 3)

# %%
from matplotlib.pyplot import imshow
imshow(test_array, interpolation="nearest")

# %%
df_finish = pd.read_csv('./Face-Pose-Net/output_render/output_preproc.csv', header=None)

# %%
df_finish[0]
# Out:
# 0            1639468949520
# 1       1639468949520_flip
# 2            1639468871304
# 3       1639468871304_flip
# 4            1639468889659
#                ...
# 2073    1640780669525_flip
# 2074         1640781265747
# 2075    1640781265747_flip
# 2076         1640780968234
# 2077    1640780968234_flip
# Name: 0, Length: 2078, dtype: object
